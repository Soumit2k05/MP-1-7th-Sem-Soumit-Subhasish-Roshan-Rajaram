# %% [markdown]
# # 02_EDA.ipynb - Exploratory Data Analysis Plan

# %% [markdown]
# ## EDA Plan
#
# 1. Generate a time series plot of power consumption.
# 2. Create histograms of key variables.
# 3. Generate a correlation heatmap between features.
# 4. Create monthly and weekly consumption trend charts.
# 5. Create an hour-wise average consumption trend to identify peak usage hours.
